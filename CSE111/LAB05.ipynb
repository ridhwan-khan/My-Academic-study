# %% [markdown]
# CSE 111 - LAB 05 -- OPERATOR OVERLOADING

# %%
#TASK O1 
#Write your code here
class Marks:
    def __init__ (self,marks):
        self.mark = marks

    def __add__(self,other):
        return Marks(self.mark + other.mark) 
    
#Do not change the following lines of code    
Q1 = Marks(int(input("Quiz 1 (out of 10): ")))
Q2 = Marks(int(input("Quiz 2 (out of 10): ")))
Lab = Marks(int(input("Lab (out of 30): ")))
Mid = Marks(int(input("Mid (out of 20): ")))
Final = Marks(int(input("Final (out of 30): ")))
total = Q1 + Q2 + Lab + Mid + Final                 #value + obj hoy na so object return kore jog korsi

print("Total marks: {}".format(total.mark))
# Out:
# Total marks: 24

# %%
#task 02
class Teacher:
    def __init__(self,name,dpt):
        self.__name = name
        self.__department = dpt
        self.__course = [] 
        
    def addCourse (self,obj):
        self.__course.append (obj.course)
    
    def printDetail(self):
        print(f'''==========================================
Name:{self.__name} 
Department: {self.__department} \n
List of courses:
==========================================''')
        print("\n".join(self.__course))
    
class Course:
    def __init__(self,course):
        self.course = course
        
    
    
# Write your code here for subtasks 1-4
    
t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")                          
c1 = Course("CSE 110 Programming Language I")                           
c2 = Course("CSE 111 Programming Language-II")                           
c3 = Course("CSE 220 Data Structures")                           
c4 = Course("CSE 221 Algorithms")                           
c5 = Course("CCSE 230 Discrete Mathematics")                           
c6 = Course("CSE 310 Object Oriented Programming")                           
c7 = Course("CSE 320 Data Communications")                          
c8 = Course("CSE 340 Computer Architecture") 
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name:Saad Abdullah
# Department: CSE
#
# List of courses:
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name:Mumit Khan
# Department: CSE
#
# List of courses:
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CCSE 230 Discrete Mathematics
# ...
# Name:Sadia Kazi
# Department: CSE
#
# List of courses:
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture

# %%
#task 03 
# Write your code here for subtasks 1-4
class Team:
    def __init__(self,name=None):
        
        self.__teamName = name
        self.__playerNameList = []
        
    def addPlayer(self,obj):
        self.__playerNameList.append(obj.playerName)
        
    def setName(self,name):
        self.__teamName = name
    
    def printDetail(self):
        print(f'''=====================
Team:{self.__teamName}
List of players: 
{self.__playerNameList}''')
        
    
class Player:
    def __init__(self,playerName):
        self.playerName = playerName

b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team:Bangladesh
# List of players:
# ['Mashrafi', 'Tamim']
# ...
# Team:Australia
# List of players:
# ['Ponting', 'Lee']

# %%
#task 04 
#Write your code here

#Do not change the following lines of code    
class Color:
    # check = []
    def __init__(self,clr):
        self.combo = {["red","yellow"]:"Orange",  ["red","blue"]: "Violet", ["yellow","blue"]: "Green" }
        self.color = clr 
        self.clr = None
    def __add__(self,other):
        check = []
        check.append(self.color)
        check.append(other.color) 
        if check in self.combo.keys():
            



C1 = Color(input("First Color: ").lower())
C2 = Color(input("Second Color: ").lower())
C3 = C1 + C2
print("Color formed:", C3.clr)

# %%
#task 04
#Write your code here
class Color:
    def __init__(self, name, clr = None):
        self.name = name
        self.clr = clr

    def __add__(self, other):
        new = self.name + other.name
        if (self.name == 'red' and other.name == 'yellow') or(self.name == 'yellow' and other.name == 'red'):
            self.clr = 'Orange'
        elif (self.name == 'blue' and other.name == 'yellow') or(self.name == 'yellow' and other.name == 'blue'):
            self.clr = 'Green'
        elif (self.name == 'red' and other.name == 'blue') or(self.name == 'blue' and other.name == 'red'):
            self.clr = 'Violet'
        return Color(self.name, self.clr)
    
C1 = Color(input("First Color: ").lower())
C2 = Color(input("Second Color: ").lower())
C3 = C1 + C2
print("Color formed:", C3.clr)
# Out:
# Color formed: Violet

# %%
#task 05 
# Write your code here for subtasks 1-5

class Circle:
    def __init__(self,rad):
        self.__rad = None
        self.setRadius(rad)
        
    def setRadius(self,rad):
        self.__rad = rad 
        
    def getRadius(self):
        return self.__rad
    
    def area(self):
        import
    
    def __add__(self,other):
        return Circle(self.__rad  + other.__rad)
c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" ,c1.area())
 
c2 = Circle(5)
print("Second circle radius:" ,c2.getRadius())
print("Second circle area:" ,c2.area())
 
c3 = c1 + c2 
print("Third circle radius:" ,c3.getRadius())
print("Third circle area:" ,c3.area())
# Out:
#   Cell In [1], line 16
#     import
#           ^
# SyntaxError: invalid syntax

# %%
#task 06 
# Write your code here for subtasks 1-5
class Triangle:
    
    def __init__(self,base,height):
        self.__base = None
        self.__height = None
        self.__area = None
        self.setBase(base)
        self.setHeight(height)
    
    def area(self):
        self.__area = 1/2 * self.getHeight() * self.getBase()
        return self.__area
    
    def getHeight(self):
        return self.__height
    
    def getBase(self):
        return self.__base
    
    def setHeight(self,height):
        self.__height = height
        
    def setBase(self,base):
        self.__base = base
    def __sub__(self , other):
        return Triangle (self.__base - other.__base , self.__height - other.__height)        
    
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())
 
t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
 
t3 = t1 - t2 
print("Third Triangle Base:" , t3.getBase())
print("Third Triangle Height:" , t3.getHeight())
print("Third Triangle area:" ,t3.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5
# Third Triangle Base: 5
# Third Triangle Height: 2
# Third Triangle area: 5.0

# %%
##task 07 
# # Write your code here
class Dolls:
    def __init__(self,name,price,flag = True):
        
        self.price = price
        self.name = name
        self.flag=flag

    def detail(self):
        if self.flag == True:
            return f'''Doll: {self.name}
Price: {self.price} taka'''
        else:
            return f'''Dolls: {self.name}
Price: {self.price} taka'''
    
    def __gt__(self,other):
        if self.price > other.price:
            return True
        else:
            return False
    
    def __add__(self,other):
        return Dolls(self.name+other.name , self.price+other.price,False)
                

obj_1 = Dolls("Tweety", 2500)
print(obj_1.detail())
if obj_1 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")

print("=========================")
obj_2 = Dolls("Daffy Duck", 1800) 
print(obj_2.detail())
if obj_2 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")

print("=========================")
obj_3 = Dolls("Bugs Bunny", 3000)
print(obj_3.detail())
if obj_3 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")

print("=========================")
obj_4 = Dolls("Porky Pig", 1500)
print(obj_4.detail())
if obj_4 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")

print("=========================")
obj_5 = obj_2 + obj_3
print(obj_5.detail())
if obj_5 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")
# Out:
# Doll: Tweety
# Price: 2500 taka
# Thank you!
# ...
# Doll: Daffy Duck
# Price: 1800 taka
# Thank you!
# ...
# Doll: Bugs Bunny
# Price: 3000 taka
# Congratulations! You get the Tweety as a gift!
# ...
# Doll: Porky Pig
# Price: 1500 taka
# Thank you!
# ...
# Dolls: Daffy DuckBugs Bunny
# Price: 4800 taka
# Congratulations! You get the Tweety as a gift!

# %%
#task 08
#Write your code here
class Coordinates:
    def __init__(self,x,y):
        self.x = x
        self.y = y
        
        
    def detail(self):
        return f"({self.x},{self.y})"
         
    
     
    def __sub__(self , other):
        return Coordinates(self.x - other.x , self.y - other.y ) 
       
    def __mul__(self,other): 
        return Coordinates(self.x * other.x , self.y * other.y ) 
    
    def __eq__(self , other):
        if self.x == other.x and self.y == other.y:
            return "The calculated coordinates are the same."
        else:
            return "The calculated coordinates are NOT the same." 


#Do not change the following lines of code 

p1 = Coordinates(int(input()),int(input()))
p2 = Coordinates(int(input()),int(input()))

p4 = p1 - p2 
print(p4.detail())

p5 = p1 * p2
print(p5.detail())

point_check = (p4 == p5)
print(point_check)
# Out:
# (0,0)
# (0,0)
# The calculated coordinates are the same.
