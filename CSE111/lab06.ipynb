# %%
#1
class Student:
    id=0
    def __init__(self,name,dep,age,cg):
        self.name=name
        self.dep=dep
        self.age=age
        self.cg=cg
        Student.id+=1
    @classmethod
    def from_String(cls,det):
        name,dep,age,cg=det.split("-")
        # cls.name=name
        # cls.dep=dep
        # cls.age=int(age)
        # cls.cg=float(cg)
        return cls(name,dep,int(age),float(cg))
    def showDetails(self):
        print(f"ID:{Student.id}\nName:{self.name}\nDepartment:{self.dep}\nAge:{self.age}\nCgpa:{self.cg}")


s1 = Student("Samin", "CSE", 21, 3.91)
print(type(Student))
# s1.showDetails()
# print("-----------------------")
# s2 = Student("Fahim", "ECE", 21, 3.85)
# s2.showDetails()
# print("-----------------------")
# s3 = Student("Tahura", "EEE", 22, 3.01)
# s3.showDetails()
# print("-----------------------")
# s4 = Student.from_String("Sumaiya-BBA-23-3.96")
# s4.showDetails()
# Out:
# <class 'type'>

# %%
class Assassin:
    n=0
    def __init__(self,name,rate):
        self.name=name
        self.rate=rate
        Assassin.n+=1
    @classmethod
    def failureRate(cls,name,rate):
        cls.rate=rate
        rate=100-cls.rate
        return cls(name,rate)
    @classmethod
    def failurePercentage(cls,name,rate):
        cls.rate=int(rate[:-1:])
        rate2=100-cls.rate
        return cls(name,rate2)
    def printDetails(self):
        print(f"Name:{self.name}\nSuccess rate:{self.rate}%\nTotal number of Assassin:{Assassin.n}")

john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage("Akabane", "10%")
akabane.printDetails()

# %%
#4
class Travel:
    count=0
    def __init__(self,source,des):
        self.source=source
        self.des=des
        Travel.count+=1
        self.t=1
    def set_time(self,t):
        self.t=t


    def set_destination(self,des):
        self.des=des
    def get_destination(self):
        return self.des
    def set_source(self,source):
        self.source=source
    def get_source(self):
        return self.source
    def display_travel_info(self):
        return (f"Source:{self.source}\nDestination:{self.des}\nFlight Time:{self.t}:00")
print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)

# %%
#4
class Travel:
    count=0
    def __init__(self,source,des):
        self.source=source
        self.des=des
        Travel.count+=1
        self.t=1
    def set_time(self,t):
        self.t=t


    def set_destination(self,des):
        self.des=des
    def get_destination(self):
        return self.des
    def set_source(self,source):
        self.source=source
    def get_source(self):
        return self.source
    def display_travel_info(self):
        return (f"Source:{self.source}\nDestination:{self.des}\nFlight Time:{self.t}:00")
print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source:Dhaka
# Destination:India
# Flight Time:1:00
# ...
# Source:Kuala Lampur
# Destination:Dhaka
# Flight Time:23:00
# ...
# Source:Dhaka
# Destination:Germany
# Flight Time:15:00
# ...
# Source:Malaysia
# Destination:Canada
# Flight Time:9:00
# ...
# No. of Traveller = 4

# %%
#6
class Laptop:
    laptopCount=0
    def __init__(self,name,count):
        self.name=name
        self.count=count
        Laptop.laptopCount+=count
    @staticmethod
    def advantage():
        print("Laptops are portable")
    @classmethod
    def resetCount(cls):
        Laptop.laptopCount=0



lenovo = Laptop("Lenovo", 5);
dell = Laptop("Dell", 7);
print(lenovo.name, lenovo.count)
print(dell.name, dell.count)
print("Total number of Laptops", Laptop.laptopCount)
Laptop.advantage()
Laptop.resetCount()
print("Total number of Laptops", Laptop.laptopCount)
# Out:
# Lenovo 5
# Dell 7
# Total number of Laptops 12
# Laptops are portable
# Total number of Laptops 0

# %%
#task 07
class Cat:

    Number_of_cats=0
    def __init__(self,clr,action):
        self.clr=clr
        self.action=action
        Cat.Number_of_cats+=1
    @classmethod
    def no_parameter(cls):
        return cls('White','Sitting')
    @classmethod
    def first_parameter(cls,cngclr):
        return cls(cngclr,'Sitting')
    @classmethod
    def second_parameter(cls,cng_action):
        return cls('Gray',cng_action)

    def changeColor(self,updateclr):
        self.clr=updateclr
    def printCat(self):
        print(self.clr ,'is',self.action)

# Write your code here

print("Total number of cats:", Cat.Number_of_cats)
c1 = Cat.no_parameter()
c2 = Cat.first_parameter("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c5 = Cat.second_parameter("playing")
print("=======================")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c5.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# White is Sitting
# Black is Sitting
# Brown is jumping
# Red is purring
# Gray is playing
# Blue is Sitting
# Purple is jumping
# ...
# Total number of cats: 5

# %%
class Student:
    def __init__(self,name,inp):
        self.name = name
        self.university = Student.vname(inp)

    @classmethod
    def up_uni(cls,n):
        self.university = n
    @staticmethod
    def vname (n):
        return  n
    def details(self):
        print(f"Name: {self.name} University: {self.university}")

s1 = Student('ridhwan',"nsu")
# s2 = Student("SHUVO vai")

s1.details()
# s2.details()
# Student.vname("nsu")
# Student.up_uni("nsu")
# Out:
# Name: ridhwan University: nsu

# %%
#task 01
class Student:
    ID = 0
    def __init__(self, name, dpt, age, cgpa):
        self.name = name
        self.dpt = dpt
        self.age = age
        self.cgpa = cgpa
        Student.ID += 1

    @classmethod
    def from_String(cls, data):
        name, dpt , age, cgpa = data.split("-")
        return cls(name, dpt, age, cgpa)
    def showDetails(self):
        print(f'''ID:{self.ID}
Name: {self.name}
Department: {self.dpt}
Age: {self.age}
CGPA: {self.cgpa}''')




s1 = Student("Samin", "CSE", 21, 3.91)
s1.showDetails()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.showDetails()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.showDetails()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.showDetails()
# Write the answer of subtask 5 here
print("Class variables are initialized outside the constructor but inside the class and instance variable are used inside the constructor everytime the constructor runs or the class is being called the instance variables gets cleared away but class variables works like a template so the class variables don't flush away.")
# Write the answer of subtask 6 here
print("An instance method mainly takes the location of the constructor whihc is usually passed in the self but the class method takes the cls location and we can return somethig to the constructor directly to the class constructor  .")
# Out:
# ID:1
# Name: Samin
# Department: CSE
# Age: 21
# CGPA: 3.91
# -----------------------
# ID:2
# Name: Fahim
# Department: ECE
# Age: 21
# CGPA: 3.85
# -----------------------
# ID:3
# Name: Tahura
# Department: EEE
# Age: 22
# CGPA: 3.01
# -----------------------
# ID:4
# Name: Sumaiya
# Department: BBA
# Age: 23
# CGPA: 3.96

# %%
#task 02
# Write your code here
class Assassin:
    n_assasin = 0
    def __init__(self, name, success):
        self.name = name
        self.success = success
        Assassin.n_assasin += 1
        
    @classmethod
    def failureRate(cls,name,failR):
        success = 100- failR
        name = name
        return cls(name, success)
    
    @classmethod
    def failurePercentage(cls,name,fail):
        name = name
        success = 100 - int(fail[0:-1])
        return cls(name, success)

    def printDetails(self):
        print(f'''Name: {self.name}
Succes Rate: {self.success}
Total number of Assassins: {Assassin.n_assasin}''')



john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage("Akabane", "10%")
akabane.printDetails()
# Out:
# Name: John Wick
# Succes Rate: 100
# Total number of Assassins: 1
# ...
# Name: Nagisa
# Succes Rate: 80
# Total number of Assassins: 2
# ...
# Name: Akabane
# Succes Rate: 90
# Total number of Assassins: 3

# %%
#task 03 
class Passenger:
    count = 0
    def __init__(self, name):
        self. name = name
        self. total = 450
        Passenger.count += 1
    def set_bag_weight(self, weight):
        
        if weight< 20 :
            pass
        
        elif 21<= weight <= 50 :
            self.total += 50 
        
        else:
            self.total += 100
        
    def printDetail(self):
        print(f'''Name:{self.name}
Bus fare: {self.total}''')
         
         
            

print("Total Passenger:", Passenger.count)
p1 = Passenger("Jack")
p1.set_bag_weight(90)
p2 = Passenger("“Carol”")
p2.set_bag_weight(10)
p3 = Passenger("“Mike”")
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print("“Total Passenger:”", Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name:Jack
# Bus fare: 550
# ...
# Name:“Carol”
# Bus fare: 450
# ...
# Name:“Mike”
# Bus fare: 500
# ...
# “Total Passenger:” 3

# %%
#task 04 

# Write your code here
class Travel:
    count = 0 
    def __init__(self, source, destination):
        self.source = source
        self.destination = destination
        self.time = 1.00
        Travel.count += 1 #i can write Travel.count too when theres no same name clash we are good to go 
         
    def set_time(self,time):
        self.time = time
    
    def set_destination(self, destination):
        self.destination = destination
        
    def set_source(self, source):
        self.source = source
        
        
    def display_travel_info(self):
        return f'''Source: {self.source}
Destination: {self.destination}
Flight time: {self.time} '''


print("“No. of Traveller =”", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("“No. of Traveller =”", Travel.count)
# Out:
# “No. of Traveller =” 0
# ...
# Source: Dhaka
# Destination: India
# Flight time: 1.0
# ...
# Source: Kuala Lampur
# Destination: Dhaka
# Flight time: 23
# ...
# Source: Dhaka
# Destination: Germany
# Flight time: 15
# ...
# Source: Malaysia
# Destination: Canada
# Flight time: 9
# ...
# “No. of Traveller =” 4

# %%
#task 05 
# Write your code here
import datetime
class Employee:
    def __init__(self, name, workingPeriod):
        self.name = name 
        self.workingPeriod= workingPeriod
    @classmethod
    def experienceCheck(cls, period, gender):
        if gender== "male":
            g_name = "He"
        else: 
            g_name = "She"
        
        if period < 3:
            return f"{g_name} is not experienced."
        else:
            return f"{g_name} is experienced."
        
    @classmethod
    def employeeByJoiningYear(cls, name, year):
        today = datetime.date.today()
        current_year = today.year
        workingPeriod = current_year - year
        return cls(name, workingPeriod)
        
employee1 = Employee('Dororo', 3)
employee2 = Employee.employeeByJoiningYear('Harry', 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name)
print(Employee.experienceCheck(2, "male"))
print(Employee.experienceCheck(3, "female"))
# Out:
# 3
# 6
# Dororo
# Harry
# He is not experienced.
# She is experienced.

# %%
#task 06 
# Write your code here

class Laptop:
    laptopCount = 0 
    
    def __init__(self, name , count):
        self.name = name 
        self.count = count
        Laptop.laptopCount += count
    
    @staticmethod
    def advantage():
        print("Laptops are portable")
    
    @staticmethod
    def resetCount(): 
        Laptop.laptopCount = 0 
        

lenovo = Laptop("Lenovo", 5);
dell = Laptop("Dell", 7);
print(lenovo.name, lenovo.count)
print(dell.name, dell.count)
print("Total number of Laptops", Laptop.laptopCount)
Laptop.advantage()
Laptop.resetCount()
print("Total number of Laptops", Laptop.laptopCount)
# Out:
# Lenovo 5
# Dell 7
# Total number of Laptops 12
# Laptops are portable
# Total number of Laptops 0

# %%
#task 07 
class Cat:
    Number_of_cats = 0 
    def __init__(self, color = "White", behaviour = "sitting"):
        self.color = color 
        self.behaviour = behaviour
        Cat.Number_of_cats += 1
    
    @classmethod
    def no_parameter(cls):
        return cls()
    
    @classmethod
    def first_parameter(cls, clr):
        return cls(clr)
    
    @classmethod
    def second_parameter(cls, bhv):
        behaviour = bhv
        return cls("White", behaviour)

    def printCat(self):
        print(f"{self.color} cat is {self.behaviour}")
    
    def changeColor(self, color):
        self.color = color
    
    
print("Total number of cats:", Cat.Number_of_cats)
c1 = Cat.no_parameter()
c2 = Cat.first_parameter("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c5 = Cat.second_parameter("playing")
print("=======================")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c5.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# White cat is playing
# Blue cat is sitting
# Purple cat is jumping
# ...
# Total number of cats: 5

# %%
#task 08
# Write your code here
import math
class Cylinder:
    radius = 5
    height = 18
    def __init__(self, radius, height):
        print(f"Default radius = {Cylinder.radius} and height = {Cylinder.height}")
        Cylinder.height = height
        Cylinder.radius = radius
        print(f"updated: radius = {Cylinder.radius} height = {Cylinder.height}")
        
    @classmethod
    def swap(cls, height, radius):
        return cls(radius, height)
    
    @classmethod
    def changeFormat(cls, data):
        height, radius = data.split("-")
        return cls (float(height),float(radius))
    @staticmethod
    def area(rad, height):
        Area = 2 * math.pi * rad * (rad + height)
        print("Area: ",Area)
    @staticmethod
    def volume(rad, height):
        volume = math.pi * (rad**2) * height
        print("Volume: ",volume)
        
    
    
c1 = Cylinder(0,0)
Cylinder.area(c1.radius,c1.height)
Cylinder.volume(c1.radius,c1.height)
print("===============================")
c2 = Cylinder.swap(8,3)
# print(c2.radius)
# print(c2.height)
c2.area(c2.radius, c2.height)
c2.volume(c2.radius,c2.height)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius, c3.height)
c3.volume(c3.radius, c3.height)
print("===============================")
Cylinder(0.3,5.56).area(Cylinder.radius,Cylinder.height)
print("===============================")
Cylinder(3,5).volume(Cylinder.radius,Cylinder.height)
# Out:
# Default radius = 5 and height = 18
# updated: radius = 0 height = 0
# Area:  0.0
# Volume:  0.0
# ...
# Default radius = 0 and height = 0
# updated: radius = 3 height = 8
# Area:  207.34511513692635
# Volume:  226.1946710584651
# ...
# Default radius = 3 and height = 8
# updated: radius = 7.0 height = 13.0
# Area:  879.645943005142
# Volume:  2001.1945203366981
# ...
# Default radius = 7.0 and height = 13.0
# updated: radius = 0.3 height = 5.56
# Area:  11.045839770021711
# ...
# Default radius = 0.3 and height = 5.56
# updated: radius = 3 height = 5
# Volume:  141.3716694115407

# %%
#task 09 
class Student:
    total = 0
    nBRAC = 0
    nOther = 0
    
    
    def __init__(self, name, dpt, institute ="BRAC University"): 
        self.name = name 
        self.dpt = dpt
        self.institute = institute
        Student.total += 1
        if institute == "BRAC University":
            Student.nBRAC += 1
        else: 
            Student.nOther += 1
            
    
    @classmethod
    def createStudent(cls, name, dpt, institute ="BRAC University"):
        return cls(name, dpt, institute)
    
    @classmethod
    def printDetails(cls):
        print(f"Total Student(s): {Student.total} \nBRAC University Student(s): {Student.nBRAC} \nOther Institution Student(s): {Student.nOther}")

    def individualDetail(self):
        print(f"Name:{self.name}\nDepartment: {self.dpt}\nInstitute: {self.institute}")


Student.printDetails()
print('#########################')

mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()
 
print('========================')

harry = Student.createStudent('Harry Potter', "Defence Against Dark Arts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()

print('=========================')

levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()
# Out:
# Total Student(s): 0
# BRAC University Student(s): 0
# Other Institution Student(s): 0
# #########################
# Name:Mikasa Ackerman
# Department: CSE
# Institute: BRAC University
# ------------------------------------------
# Total Student(s): 1
# BRAC University Student(s): 1
# Other Institution Student(s): 0
# ...
# Name:Harry Potter
# Department: Defence Against Dark Arts
# Institute: Hogwarts School
# -------------------------------------------
# Total Student(s): 2
# BRAC University Student(s): 1
# Other Institution Student(s): 1
# ...
# Name:Levi Ackerman
# Department: CSE
# Institute: BRAC University
# --------------------------------------------
# Total Student(s): 3
# BRAC University Student(s): 2
# Other Institution Student(s): 1

# %%
#task 10 


# Write your code here
class SultansDine:
    totalNumberOfBranch = 0
    totalSell = 0 
    location =[]
    
    def __init__(self, area):
        self.area = area
        self.branchSell = 0
        
        SultansDine.location.append(self)
        SultansDine.totalNumberOfBranch += 1
        #ig self ta pass kore then oitar info print krbo 
          
    def sellQuantity(self, sellQuantity):
        
        if sellQuantity < 10:
            self.branchSell = sellQuantity * 300
        
        elif sellQuantity < 20:
            self.branchSell = sellQuantity * 350
        
        else:
            self.branchSell = sellQuantity * 400 
        SultansDine.totalSell += self.branchSell
        
    def branchInformation(self):
        print(f"Branch Name: {self.area} \nBranch Sell: {self.branchSell}")
        
    @classmethod
    def details(cls):
        
        print(f"Total number of branch:(s): {SultansDine.totalNumberOfBranch} \nTotal sell: {SultansDine.totalSell} Taka")
        
        if  SultansDine.location != 0 :
            
            for i in SultansDine.location:
                branchSellPercentage = (i.branchSell / SultansDine.totalSell) * 100 
                print(f"Branch Name: {i.area}, Branch Sell: {i.branchSell} Taka \nBranch consists of total sell's:{branchSellPercentage} ")
            



SultansDine.details()
print('########################')
dhanmodi = SultansDine('Dhanmondi')
dhanmodi.sellQuantity(25)
dhanmodi.branchInformation()
print('-----------------------------------------')
SultansDine.details()

print('========================')

baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()

print('========================')

gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total number of branch:(s): 0
# Total sell: 0 Taka
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000
# -----------------------------------------
# Total number of branch:(s): 1
# Total sell: 10000 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's:100.0
# ...
# Branch Name: Baily Road
# Branch Sell: 5250
# -----------------------------------------
# Total number of branch:(s): 2
# Total sell: 15250 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's:65.57377049180327
# Branch Name: Baily Road, Branch Sell: 5250 Taka
# Branch consists of total sell's:34.42622950819672
# ...
# Branch Name: Gulshan
# Branch Sell: 2700
# -----------------------------------------
# Total number of branch:(s): 3
# Total sell: 17950 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000 Taka
# Branch consists of total sell's:55.71030640668524
# Branch Name: Baily Road, Branch Sell: 5250 Taka
# ...

# %%
class Puzzle:
    x = 0
    def methodA(self):
        Puzzle.x = 5 
        z = Puzzle.x + self.methodB(Puzzle.x)
        print(Puzzle.x, z)
        z = self.methodB(z + 2) + Puzzle.x
        print(Puzzle.x, z)
        self.methodB(Puzzle.x, z)
        print(Puzzle.x, z)
    def methodB(self, *args):
        if len(args) == 1:
            y = args[0]
            Puzzle.x = y + Puzzle.x
            print(Puzzle.x, y)
            return Puzzle.x + 3
        else:
            z, x = args
            z = z + 1
            x = x + 1
            print(z, x)
            

p = Puzzle() 
p.methodA() 
p.methodA() 
p = Puzzle()  
p.methodA() 
p.methodB(7)
# Out:
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 37 7
# 40
